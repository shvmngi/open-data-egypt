# %% [markdown]
# ## Population-Egypt 1950-2018

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotib.inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# UsageError: Line magic function `%matplotib.inline` not found.

# %%
data = pd.read_csv('population-egypt.csv')
data

# %%
data.shape

# %%
data.info()

# %%
data.describe()

# %%
data.isnull().sum()

# %%
#renaming column: Female
data.rename({'Femal':'Female'}, axis = 1, inplace = True)

# %% [markdown]
# ## Visualizing Population

# %%
'''
fig = px.line(x=data['Year'], y=data['Total'], title='Egypt Population 1950-2018', labels={'x':'Year', 'y':'Population'})
fig.show()

'''
# Out:
# "\nfig = px.line(x=data['Year'], y=data['Total'], title='Egypt Population 1950-2018', labels={'x':'Year', 'y':'Population'})\nfig.show()\n\n"

# %%
sns.lineplot(data=data, x="Year", y="Total")
plt.gcf().set_size_inches(13,4)

# %%
sns.set_theme(style="whitegrid")

ax = sns.barplot(x="Year", y="Total", data=data)
plt.gcf().set_size_inches(35,10)

# %%
'''import plotly.graph_objects as go

months = data.Year

fig = go.Figure()
fig.add_trace(go.Bar(
    x=data.Year,
    y=data.Total,
    name='Population',
    marker_color='indianred'
))


# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.show()'''
# Out:
# "import plotly.graph_objects as go\n\nmonths = data.Year\n\nfig = go.Figure()\nfig.add_trace(go.Bar(\n    x=data.Year,\n    y=data.Total,\n    name='Population',\n    marker_color='indianred'\n))\n\n\n# Here we modify the tickangle of the xaxis, resulting in rotated labels.\nfig.update_layout(barmode='group', xaxis_tickangle=-45)\nfig.show()"

# %% [markdown]
# ### Population by gender

# %%
sns.lineplot(data=data, x="Year", y="Male")
sns.lineplot(data=data, x="Year", y="Female")
plt.gcf().set_size_inches(13,4)

# %%
'''
import plotly.graph_objects as go

random_x = data.Year
random_y0 = data.Male
random_y1 = data.Female

fig = go.Figure()
fig.add_trace(go.Scatter(x=random_x, y=random_y0,
                    mode='lines',
                    name='Male'))
fig.add_trace(go.Scatter(x=random_x, y=random_y1,
                    mode='lines',
                    name='Female'))


fig.show()
'''
# Out:
# "\nimport plotly.graph_objects as go\n\nrandom_x = data.Year\nrandom_y0 = data.Male\nrandom_y1 = data.Female\n\nfig = go.Figure()\nfig.add_trace(go.Scatter(x=random_x, y=random_y0,\n                    mode='lines',\n                    name='Male'))\nfig.add_trace(go.Scatter(x=random_x, y=random_y1,\n                    mode='lines',\n                    name='Female'))\n\n\nfig.show()\n"

# %%
'''
#stacked bar chart

fig = go.Figure()
fig.add_trace(go.Bar(
    x=data.Year,
    y=data.Male,
    name='Male',
    marker_color='blue'
))
fig.add_trace(go.Bar(
    x=data.Year,
    y=data.Female,
    name='Female',
    marker_color='red'
))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.show()
'''
# Out:
# "\n#stacked bar chart\n\nfig = go.Figure()\nfig.add_trace(go.Bar(\n    x=data.Year,\n    y=data.Male,\n    name='Male',\n    marker_color='blue'\n))\nfig.add_trace(go.Bar(\n    x=data.Year,\n    y=data.Female,\n    name='Female',\n    marker_color='red'\n))\n\n# Here we modify the tickangle of the xaxis, resulting in rotated labels.\nfig.update_layout(barmode='group', xaxis_tickangle=-45)\nfig.show()\n"

# %% [markdown]
# ### Population by geographic area

# %%
plt.figure(figsize=(15,8)) 

plt.plot(data.Year,data.Male,marker='.', color='g', label= 'Male')
plt.plot(data.Year,data.Female, marker = '+', color = 'r',label = 'Female')
plt.legend();

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(data.Year, data.Male, label='Men')
rects2 = ax.bar(data.Year, data.Female, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Population')
ax.set_title('Population by gender')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-5c0210fbbaec> in <module>
#       6 ax.set_ylabel('Population')
#       7 ax.set_title('Population by gender')
# ----> 8 ax.set_xticks(x, labels)
#       9 ax.legend()
#      10
#
# NameError: name 'x' is not defined

# %%
'''
random_y3 = data.Rural
random_y4 = data.Urban


fig = go.Figure()
fig.add_trace(go.Scatter(x=random_x, y=random_y3,
                    mode='lines',
                    name='Rural'))
fig.add_trace(go.Scatter(x=random_x, y=random_y4,
                    mode='lines',
                    name='Urban'))


fig.show()
'''
# Out:
# "\nrandom_y3 = data.Rural\nrandom_y4 = data.Urban\n\n\nfig = go.Figure()\nfig.add_trace(go.Scatter(x=random_x, y=random_y3,\n                    mode='lines',\n                    name='Rural'))\nfig.add_trace(go.Scatter(x=random_x, y=random_y4,\n                    mode='lines',\n                    name='Urban'))\n\n\nfig.show()\n"

# %%
plt.figure(figsize=(15,8)) 

plt.plot(data.Year,data.Rural,marker='.', color='r', label= 'rural')
plt.plot(data.Year,data.Urban, marker = '+', color = 'g',label = 'urban')
plt.legend();
